# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting statsmodels==0.12.2
#   Downloading statsmodels-0.12.2-cp37-cp37m-manylinux1_x86_64.whl (9.5 MB)
# Collecting fbprophet==0.7.1
#   Downloading fbprophet-0.7.1.tar.gz (64 kB)
# Collecting pmdarima==1.8.0
#   Downloading pmdarima-1.8.0-cp37-cp37m-manylinux1_x86_64.whl (1.5 MB)
# Requirement already satisfied: pandas>=0.21 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from statsmodels==0.12.2->-r ./requirements.txt (line 1)) (1.2.4)
# Collecting patsy>=0.5
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Requirement already satisfied: numpy>=1.15 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from statsmodels==0.12.2->-r ./requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: scipy>=1.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from statsmodels==0.12.2->-r ./requirements.txt (line 1)) (1.6.3)
# Collecting Cython>=0.22
#   Downloading Cython-0.29.23-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
# Collecting cmdstanpy==0.9.5
#   Downloading cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Collecting pystan>=2.14
#   Downloading pystan-3.2.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: matplotlib>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fbprophet==0.7.1->-r ./requirements.txt (line 2)) (3.4.2)
# Collecting LunarCalendar>=0.0.9
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting convertdate>=2.1.2
#   Downloading convertdate-2.3.2-py3-none-any.whl (47 kB)
# Collecting holidays>=0.10.2
#   Downloading holidays-0.11.1-py3-none-any.whl (133 kB)
# Collecting setuptools-git>=1.2
#   Downloading setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from fbprophet==0.7.1->-r ./requirements.txt (line 2)) (2.8.1)
# Requirement already satisfied: tqdm>=4.36.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fbprophet==0.7.1->-r ./requirements.txt (line 2)) (4.61.0)
# Collecting Cython>=0.22
#   Downloading Cython-0.29.17-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
# Requirement already satisfied: urllib3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pmdarima==1.8.0->-r ./requirements.txt (line 3)) (1.26.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /root/venv/lib/python3.7/site-packages (from pmdarima==1.8.0->-r ./requirements.txt (line 3)) (57.0.0)
# Requirement already satisfied: joblib>=0.11 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pmdarima==1.8.0->-r ./requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: scikit-learn>=0.22 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pmdarima==1.8.0->-r ./requirements.txt (line 3)) (0.24.2)
# Collecting pymeeus<=1,>=0.3.13
#   Downloading PyMeeus-0.5.11.tar.gz (5.4 MB)
# Requirement already satisfied: pytz>=2014.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from convertdate>=2.1.2->fbprophet==0.7.1->-r ./requirements.txt (line 2)) (2021.1)
# Collecting hijri-converter
#   Downloading hijri_converter-2.1.2-py3-none-any.whl (14 kB)
# Collecting korean-lunar-calendar
#   Downloading korean_lunar_calendar-0.2.1-py3-none-any.whl (8.0 kB)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from holidays>=0.10.2->fbprophet==0.7.1->-r ./requirements.txt (line 2)) (1.16.0)
# Collecting ephem>=3.7.5.3
#   Downloading ephem-3.7.7.1-cp37-cp37m-manylinux2010_x86_64.whl (1.2 MB)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=2.0.0->fbprophet==0.7.1->-r ./requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=2.0.0->fbprophet==0.7.1->-r ./requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=2.0.0->fbprophet==0.7.1->-r ./requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=2.0.0->fbprophet==0.7.1->-r ./requirements.txt (line 2)) (8.2.0)
# Collecting pysimdjson<4.0,>=3.2
#   Downloading pysimdjson-3.2.0-cp37-cp37m-manylinux2014_x86_64.whl (2.4 MB)
# Collecting clikit<0.7,>=0.6
#   Downloading clikit-0.6.2-py2.py3-none-any.whl (91 kB)
# Collecting httpstan<4.6,>=4.5
#   Downloading httpstan-4.5.0-cp37-cp37m-manylinux_2_24_x86_64.whl (40.0 MB)
# Collecting aiohttp<4.0,>=3.6
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142 kB)
# Requirement already satisfied: chardet<5.0,>=2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet==0.7.1->-r ./requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet==0.7.1->-r ./requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet==0.7.1->-r ./requirements.txt (line 2)) (3.10.0.0)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp37-cp37m-manylinux2014_x86_64.whl (294 kB)
# Collecting pylev<2.0,>=1.3
#   Downloading pylev-1.4.0-py2.py3-none-any.whl (6.1 kB)
# Collecting crashtest<0.4.0,>=0.3.0
#   Downloading crashtest-0.3.1-py3-none-any.whl (7.0 kB)
# Collecting pastel<0.3.0,>=0.2.0
#   Downloading pastel-0.2.1-py2.py3-none-any.whl (6.0 kB)
# Collecting marshmallow<4.0,>=3.10
#   Downloading marshmallow-3.12.1-py2.py3-none-any.whl (47 kB)
# Collecting webargs<8.0,>=7.0
#   Downloading webargs-7.0.1-py2.py3-none-any.whl (30 kB)
# Collecting lz4<4.0,>=3.1
#   Downloading lz4-3.1.3-cp37-cp37m-manylinux2010_x86_64.whl (1.8 MB)
# Requirement already satisfied: appdirs<2.0,>=1.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from httpstan<4.6,>=4.5->pystan>=2.14->fbprophet==0.7.1->-r ./requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn>=0.22->pmdarima==1.8.0->-r ./requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: idna>=2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet==0.7.1->-r ./requirements.txt (line 2)) (2.10)
# Building wheels for collected packages: fbprophet, pymeeus
#   Building wheel for fbprophet (setup.py): started
#   Building wheel for fbprophet (setup.py): finished with status 'error'
#   Running setup.py clean for fbprophet
#   Building wheel for pymeeus (setup.py): started
#   Building wheel for pymeeus (setup.py): finished with status 'done'
#   Created wheel for pymeeus: filename=PyMeeus-0.5.11-py3-none-any.whl size=730983 sha256=d96887e43d7fd352699814308382d639e93a02b8944cddd7a7b2cb81cc168c4c
#   Stored in directory: /root/.cache/pip/wheels/33/6b/a6/1d9dae2323750f635654952afc74aa8f2d982cded163f43895
# Successfully built pymeeus
# Failed to build fbprophet
# Installing collected packages: multidict, yarl, marshmallow, async-timeout, webargs, pymeeus, pylev, pastel, lz4, crashtest, aiohttp, pysimdjson, patsy, korean-lunar-calendar, httpstan, hijri-converter, ephem, convertdate, clikit, statsmodels, setuptools-git, pystan, LunarCalendar, holidays, Cython, cmdstanpy, pmdarima, fbprophet
#     Running setup.py install for fbprophet: started
#     Running setup.py install for fbprophet: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: /root/venv/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/setup.py'"'"'; __file__='"'"'/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-1n_opzvs
#        cwd: /tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/
#   Complete output (44 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   creating build/lib/fbprophet
#   creating build/lib/fbprophet/stan_model
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/setup.py", line 149, in <module>
#       long_description_content_type='text/markdown',
#     File "/root/venv/lib/python3.7/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/usr/local/lib/python3.7/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/usr/local/lib/python3.7/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/usr/local/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/root/venv/lib/python3.7/site-packages/wheel/bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "/usr/local/lib/python3.7/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/usr/local/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/usr/local/lib/python3.7/distutils/command/build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "/usr/local/lib/python3.7/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/usr/local/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/setup.py", line 48, in run
#       build_models(target_dir)
#     File "/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/setup.py", line 36, in build_models
#       from fbprophet.models import StanBackendEnum
#     File "/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/fbprophet/__init__.py", line 8, in <module>
#       from fbprophet.forecaster import Prophet
#     File "/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/fbprophet/forecaster.py", line 17, in <module>
#       from fbprophet.make_holidays import get_holiday_names, make_holidays_df
#     File "/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/fbprophet/make_holidays.py", line 14, in <module>
#       import fbprophet.hdays as hdays_part2
#     File "/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/fbprophet/hdays.py", line 13, in <module>
#       from convertdate.islamic import from_gregorian, to_gregorian
#   ModuleNotFoundError: No module named 'convertdate'
#   ----------------------------------------
#   ERROR: Failed building wheel for fbprophet
#     ERROR: Command errored out with exit status 1:
#      command: /root/venv/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/setup.py'"'"'; __file__='"'"'/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-n39vgmb8/install-record.txt --single-version-externally-managed --compile --install-headers /root/venv/include/site/python3.7/fbprophet
#          cwd: /tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/
#     Complete output (40 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib
#     creating build/lib/fbprophet
#     creating build/lib/fbprophet/stan_model
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/setup.py", line 149, in <module>
#         long_description_content_type='text/markdown',
#       File "/root/venv/lib/python3.7/site-packages/setuptools/__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "/usr/local/lib/python3.7/distutils/core.py", line 148, in setup
#         dist.run_commands()
#       File "/usr/local/lib/python3.7/distutils/dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "/usr/local/lib/python3.7/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/root/venv/lib/python3.7/site-packages/setuptools/command/install.py", line 61, in run
#         return orig.install.run(self)
#       File "/usr/local/lib/python3.7/distutils/command/install.py", line 545, in run
#         self.run_command('build')
#       File "/usr/local/lib/python3.7/distutils/cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "/usr/local/lib/python3.7/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/usr/local/lib/python3.7/distutils/command/build.py", line 135, in run
#         self.run_command(cmd_name)
#       File "/usr/local/lib/python3.7/distutils/cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "/usr/local/lib/python3.7/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/setup.py", line 48, in run
#         build_models(target_dir)
#       File "/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/setup.py", line 38, in build_models
#         StanBackendEnum.get_backend_class(backend).build_model(target_dir, MODEL_DIR)
#       File "/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/fbprophet/models.py", line 209, in build_model
#         import pystan
#     ModuleNotFoundError: No module named 'pystan'
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /root/venv/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/setup.py'"'"'; __file__='"'"'/tmp/pip-install-u7no0vwu/fbprophet_a399bc5b924c4cf7b1b87aee98eb6764/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-n39vgmb8/install-record.txt --single-version-externally-managed --compile --install-headers /root/venv/include/site/python3.7/fbprophet Check the logs for full command output.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-1-0614f64dd23b> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', '# If your project has a \'requirements.txt\' file, we\'ll install it here apart from blacklisted packages that interfere with Deepnote (see above).\nif test -f requirements.txt\n  then\n    sed -i \'/jedi/d;/jupyter/d;\' ./requirements.txt\n    pip install -r ./requirements.txt\n  else echo "There\'s no requirements.txt, so nothing to install. This is the case with most projects."\nfi\n')
#
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2401             with self.builtin_trap:
#    2402                 args = (magic_arg_s, cell)
# -> 2403                 result = fn(*args, **kwargs)
#    2404             return result
#    2405
#
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'# If your project has a \'requirements.txt\' file, we\'ll install it here apart from blacklisted packages that interfere with Deepnote (see above).\nif test -f requirements.txt\n  then\n    sed -i \'/jedi/d;/jupyter/d;\' ./requirements.txt\n    pip install -r ./requirements.txt\n  else echo "There\'s no requirements.txt, so nothing to install. This is the case with most projects."\nfi\n'' returned non-zero exit status 1.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5e9f19dd-fe63-47e4-96ab-256312edafbe' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
